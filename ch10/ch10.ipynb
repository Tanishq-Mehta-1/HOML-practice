# %%
import torch

X = torch.tensor([[1.0, 4.0, 7.0], [2.0, 3.0, 6.0]], dtype=torch.float64)
X
# Out:
# tensor([[1., 4., 7.],
#         [2., 3., 6.]], dtype=torch.float64)

# %%
X @ X.T
# Out:
# tensor([[66., 56.],
#         [56., 49.]], dtype=torch.float64)

# %%
import numpy as np

torch.Tensor(np.array([[1.0, 4.0, 7.0], [2.0, 3.0, 6]])).dtype
# Out:
# torch.float32

# %%
X[:, 1] = -99
# Out:
# tensor([[ 1., 99.,  7.],
#         [ 2., 99.,  6.]], dtype=torch.float64)
